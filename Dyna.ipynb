# %%
import gymnasium as gym
import random
import numpy as np
import matplotlib.pyplot as plt
from collections import deque

# %%
env = gym.make('MountainCar-v0')

# %%
from dyna import DynaAgent

# %%
# Create the environment
env = gym.make('MountainCar-v0')
# Create the DynaAgent
dyna_agent = DynaAgent(decay=0.9, discr_step=[0.25, 0.05])

# Train the agent
n_episodes = 10001
episode_rewards=[]
episode_durations = []

fig,ax=plt.subplots(1,2,figsize=(11,5))

for episode in range(n_episodes):
    state,_ = env.reset()
    total_reward = 0
    solved=False
    done = False
    x=[state[0]]
    v=[state[1]]
    n_itr=0
    while not done:
        action = dyna_agent.select_action(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        dyna_agent.update(state, action, reward, next_state)
        solved=terminated
        done= terminated or truncated
        state = next_state
        total_reward += reward
        n_itr+=1
        x.append(state[0])  
        v.append(state[1])

    dyna_agent.decay_epsilon(episode)
    
    episode_rewards.append(total_reward) 
    episode_durations.append(n_itr)
    
    if (episode%2000==0):
        ax[0].plot(list(range(n_itr+1)),x, label=f'episode {episode}')
        ax[1].plot(x,v, label=f'episode {episode}')
        print(f'episode {episode} : solved? : {solved}')

env.close()
ax[0].set_xlabel('Episodes')
ax[0].set_ylabel('Position')
ax[1].set_xlabel('Position')
ax[1].set_ylabel('Velocity')
plt.legend()
plt.show()

dyna_agent.plot_delta_Q()
dyna_agent.plot_max_Q()

plt.plot(episode_durations, label='episode durations')
plt.plot(episode_rewards,label='episode rewards')
plt.title('Duration and total reward for each episode' )
plt.xlabel('Episodes')
plt.legend()
# Out:
# episode 0 : solved? : False
# episode 2000 : solved? : False
# episode 4000 : solved? : False
# episode 6000 : solved? : False
# episode 8000 : solved? : False
# episode 10000 : solved? : False

# %%
# Create the environment
env = gym.make('MountainCar-v0')
# Create the DynaAgent
dyna_agent = DynaAgent()

# Train the agent
n_episodes = 3001
episode_rewards=[]
episode_durations = []

fig,ax=plt.subplots(1,2,figsize=(11,5))

for episode in range(n_episodes):
    state,_ = env.reset()
    total_reward = 0
    solved=False
    done = False
    x=[state[0]]
    v=[state[1]]
    n_itr=0
    while not done:
        action = dyna_agent.select_action(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        dyna_agent.update(state, action, reward, next_state)
        solved=terminated
        done= terminated or truncated
        state = next_state
        total_reward += reward
        n_itr+=1
        x.append(state[0])  
        v.append(state[1])

    dyna_agent.decay_epsilon(episode)
    
    episode_rewards.append(total_reward) 
    episode_durations.append(n_itr)
    
    if (episode%100==0):
        print(f'episode {episode} : solved? : {solved}')
        
    if (episode%1000==0):
        ax[0].plot(list(range(n_itr+1)),x, label=f'episode {episode}')
        ax[1].plot(x,v, label=f'episode {episode}')

env.close()
ax[0].set_xlabel('Episodes')
ax[0].set_ylabel('Position')
ax[1].set_xlabel('Position')
ax[1].set_ylabel('Velocity')
plt.legend()
plt.show()

dyna_agent.plot_delta_Q()
dyna_agent.plot_max_Q()

plt.plot(list(range(n_episodes)),episode_durations, label='episode durations')
plt.plot(list(range(n_episodes)),episode_rewards,label='episode rewards')
plt.title('Duration and total reward for each episode' )
plt.legend()
# Out:
# episode 0 : solved? : False
# episode 100 : solved? : False
# episode 200 : solved? : False
# episode 300 : solved? : False
# episode 400 : solved? : False
# episode 500 : solved? : False
# episode 600 : solved? : False
# episode 700 : solved? : False
# episode 800 : solved? : False
# episode 900 : solved? : False
# episode 1000 : solved? : False
# episode 1100 : solved? : False
# episode 1200 : solved? : False
# episode 1300 : solved? : False
# episode 1400 : solved? : False
# episode 1500 : solved? : False
# episode 1600 : solved? : False
# episode 1700 : solved? : False
# episode 1800 : solved? : False
# episode 1900 : solved? : False
# episode 2000 : solved? : False
# episode 2100 : solved? : False
# episode 2200 : solved? : False
# episode 2300 : solved? : False
# episode 2400 : solved? : False
# episode 2500 : solved? : False
# episode 2600 : solved? : False
# episode 2700 : solved? : False
# episode 2800 : solved? : False
# episode 2900 : solved? : False
# episode 3000 : solved? : False

# %%
# Create the environment
env = gym.make('MountainCar-v0')
# Create the DynaAgent
dyna_agent = DynaAgent()

# Train the agent
n_episodes = 10001
episode_rewards=[]
episode_durations = []

fig,ax=plt.subplots(1,2,figsize=(11,5))

for episode in range(n_episodes):
    state,_ = env.reset()
    total_reward = 0
    solved=False
    done = False
    x=[state[0]]
    v=[state[1]]
    n_itr=0
    while not done:
        action = dyna_agent.select_action(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        dyna_agent.update(state, action, reward, next_state)
        solved=terminated
        done= terminated or truncated
        state = next_state
        total_reward += reward
        n_itr+=1
        x.append(state[0])  
        v.append(state[1])

    dyna_agent.decay_epsilon(episode)
    
    episode_rewards.append(total_reward) 
    episode_durations.append(n_itr)
    
    if (episode%100==0):
        print(f'episode {episode} : solved? : {solved}')
        
    if (episode%1000==0):
        ax[0].plot(list(range(n_itr+1)),x, label=f'episode {episode}')
        ax[1].plot(x,v, label=f'episode {episode}')

env.close()
ax[0].set_xlabel('Episodes')
ax[0].set_ylabel('Position')
ax[1].set_xlabel('Position')
ax[1].set_ylabel('Velocity')
plt.legend()
plt.show()

dyna_agent.plot_delta_Q()
dyna_agent.plot_max_Q()

plt.plot(list(range(n_episodes)),episode_durations, label='episode durations')
plt.plot(list(range(n_episodes)),episode_rewards,label='episode rewards')
plt.title('Duration and total reward for each episode' )
plt.legend()
# Out:
# episode 0 : solved? : False
# episode 100 : solved? : False
# episode 200 : solved? : False
# episode 300 : solved? : False
# episode 400 : solved? : False
# episode 500 : solved? : False
# episode 600 : solved? : False
# episode 700 : solved? : False
# episode 800 : solved? : False
# episode 900 : solved? : False
# episode 1000 : solved? : False
# episode 1100 : solved? : False
# episode 1200 : solved? : False
# episode 1300 : solved? : False
# episode 1400 : solved? : False
# episode 1500 : solved? : False
# episode 1600 : solved? : False
# episode 1700 : solved? : False
# episode 1800 : solved? : False
# episode 1900 : solved? : False
# episode 2000 : solved? : False
# episode 2100 : solved? : False
# episode 2200 : solved? : False
# episode 2300 : solved? : False
# episode 2400 : solved? : False
# episode 2500 : solved? : False
# episode 2600 : solved? : False
# episode 2700 : solved? : False
# episode 2800 : solved? : False
# episode 2900 : solved? : False
# episode 3000 : solved? : False
# episode 3100 : solved? : False
# episode 3200 : solved? : False
# episode 3300 : solved? : False
# episode 3400 : solved? : False
# episode 3500 : solved? : False
# episode 3600 : solved? : False
# episode 3700 : solved? : False
# episode 3800 : solved? : False
# episode 3900 : solved? : False
# episode 4000 : solved? : False
# episode 4100 : solved? : False
# episode 4200 : solved? : False
# episode 4300 : solved? : False
# episode 4400 : solved? : False
# episode 4500 : solved? : False
# episode 4600 : solved? : False
# episode 4700 : solved? : False
# episode 4800 : solved? : False
# episode 4900 : solved? : False
# episode 5000 : solved? : False
# episode 5100 : solved? : False
# episode 5200 : solved? : False
# episode 5300 : solved? : False
# episode 5400 : solved? : False
# episode 5500 : solved? : False
# episode 5600 : solved? : False
# episode 5700 : solved? : False
# episode 5800 : solved? : False
# episode 5900 : solved? : False
# episode 6000 : solved? : False
# episode 6100 : solved? : False
# episode 6200 : solved? : False
# episode 6300 : solved? : False
# episode 6400 : solved? : False
# episode 6500 : solved? : False
# episode 6600 : solved? : False
# episode 6700 : solved? : False
# episode 6800 : solved? : False
# episode 6900 : solved? : False
# episode 7000 : solved? : False
# episode 7100 : solved? : False
# episode 7200 : solved? : False
# episode 7300 : solved? : False
# episode 7400 : solved? : False
# episode 7500 : solved? : False
# episode 7600 : solved? : False
# episode 7700 : solved? : False
# episode 7800 : solved? : False
# episode 7900 : solved? : False
# episode 8000 : solved? : False
# episode 8100 : solved? : False
# episode 8200 : solved? : False
# episode 8300 : solved? : False
# episode 8400 : solved? : False
# episode 8500 : solved? : False
# episode 8600 : solved? : False
# episode 8700 : solved? : False
# episode 8800 : solved? : False
# episode 8900 : solved? : False
# episode 9000 : solved? : False
# episode 9100 : solved? : False
# episode 9200 : solved? : False
# episode 9300 : solved? : False
# episode 9400 : solved? : False
# episode 9500 : solved? : False
# episode 9600 : solved? : False
# episode 9700 : solved? : False
# episode 9800 : solved? : False
# episode 9900 : solved? : False
# episode 10000 : solved? : False

# %%
# Create the environment
env = gym.make('MountainCar-v0')
# Create the DynaAgent
dyna_agent = DynaAgent()

# Train the agent
n_episodes = 10001
episode_rewards=[]
episode_durations = []

fig,ax=plt.subplots(1,2,figsize=(11,5))

for episode in range(n_episodes):
    state,_ = env.reset()
    total_reward = 0
    solved=False
    done = False
    x=[state[0]]
    v=[state[1]]
    n_itr=0
    while not done:
        action = dyna_agent.select_action(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        dyna_agent.update(state, action, reward, next_state)
        solved=terminated
        done= terminated or truncated
        state = next_state
        total_reward += reward
        n_itr+=1
        x.append(state[0])  
        v.append(state[1])

    dyna_agent.decay_epsilon(episode)
    
    episode_rewards.append(total_reward) 
    episode_durations.append(n_itr)
    
    if (episode%100==0):
        print(f'episode {episode} : solved? : {solved}')
        
    if (episode%1000==0):
        ax[0].plot(list(range(n_itr+1)),x, label=f'episode {episode}')
        ax[1].plot(x,v, label=f'episode {episode}')

env.close()
ax[0].set_xlabel('Episodes')
ax[0].set_ylabel('Position')
ax[1].set_xlabel('Position')
ax[1].set_ylabel('Velocity')
plt.legend()
plt.show()

dyna_agent.plot_delta_Q()
dyna_agent.plot_max_Q()

plt.plot(list(range(n_episodes)),episode_durations, label='episode durations')
plt.plot(list(range(n_episodes)),episode_rewards,label='episode rewards')
plt.title('Duration and total reward for each episode' )
plt.legend()
# Out:
# episode 0 : solved? : False
# episode 100 : solved? : False
# episode 200 : solved? : False
# episode 300 : solved? : False
# episode 400 : solved? : False
# episode 500 : solved? : False
# episode 600 : solved? : False
# episode 700 : solved? : False
# episode 800 : solved? : False
# episode 900 : solved? : False
# episode 1000 : solved? : False
# episode 1100 : solved? : False
# episode 1200 : solved? : False
# episode 1300 : solved? : False
# episode 1400 : solved? : False
# episode 1500 : solved? : False
# episode 1600 : solved? : False
# episode 1700 : solved? : False
# episode 1800 : solved? : False
# episode 1900 : solved? : False
# episode 2000 : solved? : False
# episode 2100 : solved? : False
# episode 2200 : solved? : False
# episode 2300 : solved? : False
# episode 2400 : solved? : False
# episode 2500 : solved? : False
# episode 2600 : solved? : False
# episode 2700 : solved? : False
# episode 2800 : solved? : False
# episode 2900 : solved? : False
# episode 3000 : solved? : False
# episode 3100 : solved? : False
# episode 3200 : solved? : False
# episode 3300 : solved? : False
# episode 3400 : solved? : False
# episode 3500 : solved? : False
# episode 3600 : solved? : False
# episode 3700 : solved? : False
# episode 3800 : solved? : False
# episode 3900 : solved? : False
# episode 4000 : solved? : False
# episode 4100 : solved? : False
# episode 4200 : solved? : False
# episode 4300 : solved? : False
# episode 4400 : solved? : False
# episode 4500 : solved? : False
# episode 4600 : solved? : False
# episode 4700 : solved? : False
# episode 4800 : solved? : False
# episode 4900 : solved? : False
# episode 5000 : solved? : False
# episode 5100 : solved? : False
# episode 5200 : solved? : False
# episode 5300 : solved? : False
# episode 5400 : solved? : False
# episode 5500 : solved? : False
# episode 5600 : solved? : False
# episode 5700 : solved? : False
# episode 5800 : solved? : False
# episode 5900 : solved? : False
# episode 6000 : solved? : False
# episode 6100 : solved? : False
# episode 6200 : solved? : False
# episode 6300 : solved? : False
# episode 6400 : solved? : False
# episode 6500 : solved? : False
# episode 6600 : solved? : False
# episode 6700 : solved? : False
# episode 6800 : solved? : False
# episode 6900 : solved? : False
# episode 7000 : solved? : False
# episode 7100 : solved? : False
# episode 7200 : solved? : False
# episode 7300 : solved? : False
# episode 7400 : solved? : False
# episode 7500 : solved? : False
# episode 7600 : solved? : False
# episode 7700 : solved? : False
# episode 7800 : solved? : False
# episode 7900 : solved? : False
# episode 8000 : solved? : False
# episode 8100 : solved? : False
# episode 8200 : solved? : False
# episode 8300 : solved? : False
# episode 8400 : solved? : False
# episode 8500 : solved? : False
# episode 8600 : solved? : False
# episode 8700 : solved? : False
# episode 8800 : solved? : False
# episode 8900 : solved? : False
# episode 9000 : solved? : False
# episode 9100 : solved? : False
# episode 9200 : solved? : False
# episode 9300 : solved? : False
# episode 9400 : solved? : False
# episode 9500 : solved? : False
# episode 9600 : solved? : False
# episode 9700 : solved? : False
# episode 9800 : solved? : False
# episode 9900 : solved? : False
# episode 10000 : solved? : False
